# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\Sarang\AppData\Local\Temp\ipykernel_22976\962969891.py:4: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10690
# 1    1027     Ethereum    ETH      ethereum              8166
# 2     825  Tether USDt   USDT        tether             70379
# 3    1839          BNB    BNB           bnb              1968
# 4    5426       Solana    SOL        solana               610
# 5      52          XRP    XRP           xrp              1194
# 6    3408         USDC   USDC      usd-coin             15936
# 7    2010      Cardano    ADA       cardano              1018
# 8    5805    Avalanche   AVAX     avalanche               628
# 9      74     Dogecoin   DOGE      dogecoin               863
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


    
    
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)


    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'F:\dae portfoloio\API.csv'):
      df.to_csv(r'F:\dae portfoloio\API.csv', header='column_names')
    else:
        df.to_csv(r'F:\dae portfoloio\API.csv', mode='a', header=False)

# %% [markdown]
# import os
# from time import time
# from time import sleep
#
# for i in range(333):
#     api_runner()
#     print('API Runner completed')
#     sleep(60) #sleep for 1 minute
# exit()

# %%
df3= pd.read_csv(r'F:\dae portfoloio\API.csv')
df3
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             10690
# 1            1   1027     Ethereum    ETH      ethereum              8166
# 2            2    825  Tether USDt   USDT        tether             70379
# 3            3   1839          BNB    BNB           bnb              1968
# 4            4   5426       Solana    SOL        solana               610
# 5            5     52          XRP    XRP           xrp              1194
# 6            6   3408         USDC   USDC      usd-coin             15936
# 7            7   2010      Cardano    ADA       cardano              1018
# 8            8   5805    Avalanche   AVAX     avalanche               628
# 9            9     74     Dogecoin   DOGE      dogecoin               863
# 10          10   6636     Polkadot    DOT  polkadot-new               657
# 11          11   1958         TRON    TRX          tron               894
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10690
# 1    1027     Ethereum    ETH      ethereum              8166
# 2     825  Tether USDt   USDT        tether             70379
# 3    1839          BNB    BNB           bnb              1968
# 4    5426       Solana    SOL        solana               610
# 5      52          XRP    XRP           xrp              1194
# 6    3408         USDC   USDC      usd-coin             15936
# 7    2010      Cardano    ADA       cardano              1018
# 8    5805    Avalanche   AVAX     avalanche               628
# 9      74     Dogecoin   DOGE      dogecoin               863
# 10   6636     Polkadot    DOT  polkadot-new               657
# 11   1958         TRON    TRX          tron               894
# 12   3890      Polygon  MATIC       polygon              1219
# 13   1975    Chainlink   LINK     chainlink              1546
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# Now let's look at the coin trends over time

df2 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df2
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.03032                       0.07716
# Ethereum                         0.18531                      -0.02887
# Tether USDt                      0.03187                      -0.01170
# BNB                              1.44952                       0.83883
# Solana                           0.54868                      -3.08631
# XRP                             -0.49236                       0.56422
# USDC                             0.04108                       0.02818
# Cardano                          0.33960                      -1.37211
# Avalanche                        0.42534                      -3.72714
# Dogecoin                         0.09751                      -1.27697
# Polkadot                        -0.03914                      -1.45173
# TRON                            -0.01944                       0.85737
# ...

# %%
df4 = df2.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.03032
#              quote.USD.percent_change_24h     0.07716
#              quote.USD.percent_change_7d      6.57511
#              quote.USD.percent_change_30d     8.97428
#              quote.USD.percent_change_60d    30.15863
#              quote.USD.percent_change_90d    63.80720
# Ethereum     quote.USD.percent_change_1h      0.18531
#              quote.USD.percent_change_24h    -0.02887
#              quote.USD.percent_change_7d      6.83731
#              quote.USD.percent_change_30d     5.57075
#              quote.USD.percent_change_60d    29.74023
#              quote.USD.percent_change_90d    45.26853
# Tether USDt  quote.USD.percent_change_1h      0.03187
#              quote.USD.percent_change_24h    -0.01170
#              quote.USD.percent_change_7d      0.05880
#              quote.USD.percent_change_30d     0.05480
#              quote.USD.percent_change_60d     0.02131
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.03032
#             quote.USD.percent_change_24h   0.07716
#             quote.USD.percent_change_7d    6.57511
#             quote.USD.percent_change_30d   8.97428
#             quote.USD.percent_change_60d  30.15863
#             quote.USD.percent_change_90d  63.80720
# Ethereum    quote.USD.percent_change_1h    0.18531
#             quote.USD.percent_change_24h  -0.02887
#             quote.USD.percent_change_7d    6.83731
#             quote.USD.percent_change_30d   5.57075
#             quote.USD.percent_change_60d  29.74023
#             quote.USD.percent_change_90d  45.26853
# Tether USDt quote.USD.percent_change_1h    0.03187
#             quote.USD.percent_change_24h  -0.01170
#             quote.USD.percent_change_7d    0.05880
#             quote.USD.percent_change_30d   0.05480
#             quote.USD.percent_change_60d   0.02131
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64
